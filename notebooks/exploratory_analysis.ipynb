# %% [markdown]
# # Smart Lender: Applicant Creditworthiness & Loan Eligibility Prediction
#
# Smart Lender is a machine learning-powered application designed to evaluate loan applicants' profiles and predict whether they are eligible for a loan. This notebook walks through:
# 1. Data Downloading & Exploration
# 2. Exploratory Data Analysis (EDA) with visualizations
# 3. Missing value imputation (Mean/Mode)
# 4. Categorical encoding & normalization
# 5. Training & evaluating multiple classification models (Decision Tree, Random Forest, KNN, XGBoost)
# 6. Saving the best-performing model (XGBoost) for deployment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Load dataset
url = "https://raw.githubusercontent.com/dsrscientist/DSData/master/loan_prediction.csv"
df = pd.read_csv(url)
print("Data loaded successfully!")
print("Shape:", df.shape)
df.head()
